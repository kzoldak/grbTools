# %%
import pandas as pd
import numpy as np

# %%
f = "/Users/kimzoldak/GRBs/sample/Band_13_GBM+LAT__19_GBMconstrained.txt"

# %%
df = pd.read_csv(f)

# %%
df.head()
# Out:
#        trigger        name  number      z       LumDist     trigtime      t90  \
# 0  bn080916009  GRB080916C       5  4.350  1.250788e+29  54725.00886   62.977
# 1  bn090323002   GRB090323      13  3.570  9.895276e+28  54913.00188  135.170
# 2  bn090328401  GRB090328A      14  0.736  1.437554e+28  54918.40054   61.697
# 3  bn090510016   GRB090510      17  0.903  1.847659e+28  54961.01597    0.960
# 4  bn090902462  GRB090902B      20  1.822  4.387160e+28  55076.46190   19.328
#
#      t90Rest  t90start  t90stop        ...          eiso_10k10G  \
# 0  11.771402     1.280   64.257        ...         7.033527e+54
# 1  29.577681     8.192  143.362        ...         5.856712e+54
# 2  35.539747     4.352   66.049        ...         1.748318e+53
# 3   0.504467    -0.048    0.912        ...         5.557026e+52
# 4   6.849043     2.816   22.144        ...         4.237600e+54
#
#   eiso_10k10G_moe_lo eiso_10k10G_moe_up  eiso_10k10G_ci_lo  eiso_10k10G_ci_up  \
# 0       1.472875e+53       1.472875e+53       6.886240e+54       7.180815e+54
# 1       1.673934e+53       1.673934e+53       5.689319e+54       6.024106e+54
# 2       7.397752e+51       7.397752e+51       1.674340e+53       1.822295e+53
# 3       3.545276e+51       3.545276e+51       5.202498e+52       5.911553e+52
# 4       4.110050e+52       4.110050e+52       4.196499e+54       4.278700e+54
#
#      eiso_1k10M  eiso_1k10M_moe_lo  eiso_1k10M_moe_up  eiso_1k10M_ci_lo  \
# 0  3.494756e+54       7.098348e+52       7.098348e+52      3.423773e+54
# 1  4.143551e+54       9.174289e+52       9.174289e+52      4.051808e+54
# 2  1.189908e+53       3.425655e+51       3.425655e+51      1.155652e+53
# 3  2.789666e+52       1.940188e+51       1.940188e+51      2.595647e+52
# 4  3.390065e+54       2.632059e+52       2.632059e+52      3.363745e+54
#
#    eiso_1k10M_ci_up
# 0      3.565740e+54
# 1      4.235294e+54
# 2      1.224165e+53
# 3      2.983685e+52
# 4      3.416386e+54
#
# [5 rows x 104 columns]

# %%
burst = 'bn080916009'

# %%
values = []
for par in 'alpha beta epeak norm'.split():
    values.append(float(df[df.trigger == burst][par].values))

# %%
values
# Out:
# [-1.0295860000000001, -2.198223, 510.64099999999996, 0.017522454]
