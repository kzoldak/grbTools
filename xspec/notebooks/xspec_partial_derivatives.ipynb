# %%
from __future__ import division
from collections import OrderedDict
import json

from grbTools.xspec.partialderivatives import PartialDerivatives

# %%
deriv = PartialDerivatives()

# %%
deriv.modelnameOptions  # show all model names
# Out:
# ['powerlaw',
#  'lpow',
#  'bbody',
#  'grbm',
#  'sbpl',
#  'cutoffpl',
#  'grbm+lpow',
#  'sbpl+lpow',
#  'cutoffpl+lpow',
#  'grbm+powerlaw',
#  'sbpl+powerlaw',
#  'cutoffpl+powerlaw',
#  'grbm+bbody',
#  'sbpl+bbody',
#  'cutoffpl+bbody',
#  'grbm+bbody+lpow',
#  'sbpl+bbody+lpow',
#  'cutoffpl+bbody+lpow',
#  'grbm+bbody+powerlaw',
#  'sbpl+bbody+powerlaw',
#  'cutoffpl+bbody+powerlaw',
#  'bbody+lpow',
#  'bbody+powerlaw']

# %%
# Compute all partial derivatives wrt each parameter and store in an 
#   ordered dict.

allPartials = OrderedDict()

for model in deriv.modelnameOptions:
    allPartials[model] = deriv.calc_partial_derivatives(modelname=model, 
                                                        dpar=None, 
                                                        epeakUnc=False)

# %%
allPartials
# Out:
# OrderedDict([('powerlaw',
#               OrderedDict([('PhoIndex__1',
#                             '-energy*energy**(-PhoIndex__1)*norm__2*log(energy)'),
#                            ('norm__2', 'energy*energy**(-PhoIndex__1)')])),
#              ('lpow',
#               OrderedDict([('plIndex__1',
#                             'energy*norm__2*(0.01*energy)**plIndex__1*log(0.01*energy)'),
#                            ('norm__2', 'energy*(0.01*energy)**plIndex__1')])),
#              ('bbody',
#               OrderedDict([('kT__1',
#                             '8.0525*energy**4*norm__2*exp(energy/kT__1)/(kT__1**6*(exp(energy/kT__1) - 1)**2) - 32.21*energy**3*norm__2/(kT__1**5*(exp(energy/kT__1) - 1))'),
#                            ('norm__2',
#                             '8.0525*energy**3/(kT__1**4*(exp(energy/kT__1) - 1))')])),
#              ('grbm',
#               OrderedDict([('alpha__1',
#                             ['energy*norm__4*(0.01*energy)**alpha__1*exp(-energy/tem__3)*log(0.01*energy)',
#                              'energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(log(0.01*tem__3*(alpha__1 - beta__2)) + 1.0)*exp(-alpha__1 + beta__2) - energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)']),
#                            ('beta__2',
#                             'energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(-log(0.01*tem__3*(alpha__1 - beta__2)) - 1.0)*exp(-alpha__1 + beta__2) + energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)*log(0.01*energy) + energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)'),
#                            ('tem__3',
#                             '100.0*energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(0.01*alpha__1 - 0.01*beta__2)*exp(-alpha__1 + beta__2)/tem__3'),
#                            ('norm__4',
#                             'energy*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)')])),
#              ('sbpl',
#               OrderedDict([('alpha__1',
#                             '10**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(0.15*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) - 0.15*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*log(10) + 0.5*10**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy)'),
#                            ('beta__2',
#                             '10**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(-0.15*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + 0.15*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*log(10) + 0.5*10**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy)'),
#                            ('ebreak__3',
#                             '10**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*((-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(energy/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(energy/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))) - (-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(100.0/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(100.0/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))))*log(10)'),
#                            ('norm__4',
#                             '10**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)')])),
#              ('cutoffpl',
#               OrderedDict([('PhoIndex__1',
#                             '-energy*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)*log(energy)'),
#                            ('HighECut__2',
#                             'energy**2*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)/HighECut__2**2'),
#                            ('norm__3',
#                             'energy*energy**(-PhoIndex__1)*exp(-energy/HighECut__2)')])),
#              ('grbm+lpow',
#               OrderedDict([('alpha__1',
#                             ['energy*norm__4*(0.01*energy)**alpha__1*exp(-energy/tem__3)*log(0.01*energy)',
#                              'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(log(0.01*tem__3*(alpha__1 - beta__2)) + 1.0)*exp(-alpha__1 + beta__2) - norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))']),
#                            ('beta__2',
#                             'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(-log(0.01*tem__3*(alpha__1 - beta__2)) - 1.0)*exp(-alpha__1 + beta__2) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)*log(0.01*energy) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))'),
#                            ('tem__3',
#                             '100.0*energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(0.01*alpha__1 - 0.01*beta__2)*exp(-alpha__1 + beta__2)/tem__3'),
#                            ('norm__4',
#                             'energy*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)'),
#                            ('plIndex__5',
#                             'energy*norm__6*(0.01*energy)**plIndex__5*log(0.01*energy)'),
#                            ('norm__6', 'energy*(0.01*energy)**plIndex__5')])),
#              ('sbpl+lpow',
#               OrderedDict([('alpha__1',
#                             'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) - 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            ('beta__2',
#                             'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(-0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            ('ebreak__3',
#                             '10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(energy/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(energy/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))) - 2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(100.0/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(100.0/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))))'),
#                            ('norm__4',
#                             '10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)'),
#                            ('plIndex__5',
#                             'energy*norm__6*(0.01*energy)**plIndex__5*log(0.01*energy)'),
#                            ('norm__6', 'energy*(0.01*energy)**plIndex__5')])),
#              ('cutoffpl+lpow',
#               OrderedDict([('PhoIndex__1',
#                             '-energy*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)*log(energy)'),
#                            ('HighECut__2',
#                             'energy**2*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)/HighECut__2**2'),
#                            ('norm__3',
#                             'energy*energy**(-PhoIndex__1)*exp(-energy/HighECut__2)'),
#                            ('plIndex__4',
#                             'energy*norm__5*(0.01*energy)**plIndex__4*log(0.01*energy)'),
#                            ('norm__5', 'energy*(0.01*energy)**plIndex__4')])),
#              ('grbm+powerlaw',
#               OrderedDict([('alpha__1',
#                             ['energy*norm__4*(0.01*energy)**alpha__1*exp(-energy/tem__3)*log(0.01*energy)',
#                              'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(log(0.01*tem__3*(alpha__1 - beta__2)) + 1.0)*exp(-alpha__1 + beta__2) - norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))']),
#                            ('beta__2',
#                             'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(-log(0.01*tem__3*(alpha__1 - beta__2)) - 1.0)*exp(-alpha__1 + beta__2) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)*log(0.01*energy) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))'),
#                            ('tem__3',
#                             '100.0*energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(0.01*alpha__1 - 0.01*beta__2)*exp(-alpha__1 + beta__2)/tem__3'),
#                            ('norm__4',
#                             'energy*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)'),
#                            ('PhoIndex__5',
#                             '-energy*energy**(-PhoIndex__5)*norm__6*log(energy)'),
#                            ('norm__6', 'energy*energy**(-PhoIndex__5)')])),
#              ('sbpl+powerlaw',
#               OrderedDict([('alpha__1',
#                             'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) - 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            ('beta__2',
#                             'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(-0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            ('ebreak__3',
#                             '10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(energy/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(energy/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))) - 2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(100.0/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(100.0/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))))'),
#                            ('norm__4',
#                             '10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)'),
#                            ('PhoIndex__5',
#                             '-energy*energy**(-PhoIndex__5)*norm__6*log(energy)'),
#                            ('norm__6', 'energy*energy**(-PhoIndex__5)')])),
#              ('cutoffpl+powerlaw',
#               OrderedDict([('PhoIndex__1',
#                             '-energy*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)*log(energy)'),
#                            ('HighECut__2',
#                             'energy**2*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)/HighECut__2**2'),
#                            ('norm__3',
#                             'energy*energy**(-PhoIndex__1)*exp(-energy/HighECut__2)'),
#                            ('PhoIndex__4',
#                             '-energy*energy**(-PhoIndex__4)*norm__5*log(energy)'),
#                            ('norm__5', 'energy*energy**(-PhoIndex__4)')])),
#              ('grbm+bbody',
#               OrderedDict([('alpha__1',
#                             ['energy*norm__4*(0.01*energy)**alpha__1*exp(-energy/tem__3)*log(0.01*energy)',
#                              'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(log(0.01*tem__3*(alpha__1 - beta__2)) + 1.0)*exp(-alpha__1 + beta__2) - norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))']),
#                            ('beta__2',
#                             'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(-log(0.01*tem__3*(alpha__1 - beta__2)) - 1.0)*exp(-alpha__1 + beta__2) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)*log(0.01*energy) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))'),
#                            ('tem__3',
#                             '100.0*energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(0.01*alpha__1 - 0.01*beta__2)*exp(-alpha__1 + beta__2)/tem__3'),
#                            ('norm__4',
#                             'energy*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)'),
#                            ('kT__5',
#                             'energy*(8.0525*energy**3*norm__6*exp(energy/kT__5)/(kT__5**6*(exp(energy/kT__5) - 1)**2) - 32.21*energy**2*norm__6/(kT__5**5*(exp(energy/kT__5) - 1)))'),
#                            ('norm__6',
#                             '8.0525*energy**3/(kT__5**4*(exp(energy/kT__5) - 1))')])),
#              ('sbpl+bbody',
#               OrderedDict([('alpha__1',
#                             'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) - 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            ('beta__2',
#                             'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(-0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            ('ebreak__3',
#                             '10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(energy/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(energy/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))) - 2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(100.0/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(100.0/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))))'),
#                            ('norm__4',
#                             '10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)'),
#                            ('kT__5',
#                             'energy*(8.0525*energy**3*norm__6*exp(energy/kT__5)/(kT__5**6*(exp(energy/kT__5) - 1)**2) - 32.21*energy**2*norm__6/(kT__5**5*(exp(energy/kT__5) - 1)))'),
#                            ('norm__6',
#                             '8.0525*energy**3/(kT__5**4*(exp(energy/kT__5) - 1))')])),
#              ('cutoffpl+bbody',
#               OrderedDict([('PhoIndex__1',
#                             '-energy*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)*log(energy)'),
#                            ('HighECut__2',
#                             'energy**2*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)/HighECut__2**2'),
#                            ('norm__3',
#                             'energy*energy**(-PhoIndex__1)*exp(-energy/HighECut__2)'),
#                            ('kT__4',
#                             'energy*(8.0525*energy**3*norm__5*exp(energy/kT__4)/(kT__4**6*(exp(energy/kT__4) - 1)**2) - 32.21*energy**2*norm__5/(kT__4**5*(exp(energy/kT__4) - 1)))'),
#                            ('norm__5',
#                             '8.0525*energy**3/(kT__4**4*(exp(energy/kT__4) - 1))')])),
#              ('grbm+bbody+lpow',
#               OrderedDict([('alpha__1',
#                             ['energy*norm__4*(0.01*energy)**alpha__1*exp(-energy/tem__3)*log(0.01*energy)',
#                              'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(log(0.01*tem__3*(alpha__1 - beta__2)) + 1.0)*exp(-alpha__1 + beta__2) - norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))']),
#                            ('beta__2',
#                             'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(-log(0.01*tem__3*(alpha__1 - beta__2)) - 1.0)*exp(-alpha__1 + beta__2) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)*log(0.01*energy) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))'),
#                            ('tem__3',
#                             '100.0*energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(0.01*alpha__1 - 0.01*beta__2)*exp(-alpha__1 + beta__2)/tem__3'),
#                            ('norm__4',
#                             'energy*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)'),
#                            ('kT__5',
#                             'energy*(8.0525*energy**3*norm__6*exp(energy/kT__5)/(kT__5**6*(exp(energy/kT__5) - 1)**2) - 32.21*energy**2*norm__6/(kT__5**5*(exp(energy/kT__5) - 1)))'),
#                            ('norm__6',
#                             '8.0525*energy**3/(kT__5**4*(exp(energy/kT__5) - 1))'),
#                            ('plIndex__7',
#                             'energy*norm__8*(0.01*energy)**plIndex__7*log(0.01*energy)'),
#                            ('norm__8', 'energy*(0.01*energy)**plIndex__7')])),
#              ('sbpl+bbody+lpow',
#               OrderedDict([('alpha__1',
#                             'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) - 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            ('beta__2',
#                             'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(-0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            ('ebreak__3',
#                             '10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(energy/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(energy/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))) - 2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(100.0/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(100.0/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))))'),
#                            ('norm__4',
#                             '10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)'),
#                            ('kT__5',
#                             'energy*(8.0525*energy**3*norm__6*exp(energy/kT__5)/(kT__5**6*(exp(energy/kT__5) - 1)**2) - 32.21*energy**2*norm__6/(kT__5**5*(exp(energy/kT__5) - 1)))'),
#                            ('norm__6',
#                             '8.0525*energy**3/(kT__5**4*(exp(energy/kT__5) - 1))'),
#                            ('plIndex__7',
#                             'energy*norm__8*(0.01*energy)**plIndex__7*log(0.01*energy)'),
#                            ('norm__8', 'energy*(0.01*energy)**plIndex__7')])),
#              ('cutoffpl+bbody+lpow',
#               OrderedDict([('PhoIndex__1',
#                             '-energy*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)*log(energy)'),
#                            ('HighECut__2',
#                             'energy**2*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)/HighECut__2**2'),
#                            ('norm__3',
#                             'energy*energy**(-PhoIndex__1)*exp(-energy/HighECut__2)'),
#                            ('kT__4',
#                             'energy*(8.0525*energy**3*norm__5*exp(energy/kT__4)/(kT__4**6*(exp(energy/kT__4) - 1)**2) - 32.21*energy**2*norm__5/(kT__4**5*(exp(energy/kT__4) - 1)))'),
#                            ('norm__5',
#                             '8.0525*energy**3/(kT__4**4*(exp(energy/kT__4) - 1))'),
#                            ('plIndex__6',
#                             'energy*norm__7*(0.01*energy)**plIndex__6*log(0.01*energy)'),
#                            ('norm__7', 'energy*(0.01*energy)**plIndex__6')])),
#              ('grbm+bbody+powerlaw',
#               OrderedDict([('alpha__1',
#                             ['energy*norm__4*(0.01*energy)**alpha__1*exp(-energy/tem__3)*log(0.01*energy)',
#                              'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(log(0.01*tem__3*(alpha__1 - beta__2)) + 1.0)*exp(-alpha__1 + beta__2) - norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))']),
#                            ('beta__2',
#                             'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(-log(0.01*tem__3*(alpha__1 - beta__2)) - 1.0)*exp(-alpha__1 + beta__2) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)*log(0.01*energy) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))'),
#                            ('tem__3',
#                             '100.0*energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(0.01*alpha__1 - 0.01*beta__2)*exp(-alpha__1 + beta__2)/tem__3'),
#                            ('norm__4',
#                             'energy*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)'),
#                            ('kT__5',
#                             'energy*(8.0525*energy**3*norm__6*exp(energy/kT__5)/(kT__5**6*(exp(energy/kT__5) - 1)**2) - 32.21*energy**2*norm__6/(kT__5**5*(exp(energy/kT__5) - 1)))'),
#                            ('norm__6',
#                             '8.0525*energy**3/(kT__5**4*(exp(energy/kT__5) - 1))'),
#                            ('PhoIndex__7',
#                             '-energy*energy**(-PhoIndex__7)*norm__8*log(energy)'),
#                            ('norm__8', 'energy*energy**(-PhoIndex__7)')])),
#              ('sbpl+bbody+powerlaw',
#               OrderedDict([('alpha__1',
#                             'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) - 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            ('beta__2',
#                             'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(-0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            ('ebreak__3',
#                             '10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(energy/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(energy/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))) - 2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(100.0/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(100.0/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))))'),
#                            ('norm__4',
#                             '10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)'),
#                            ('kT__5',
#                             'energy*(8.0525*energy**3*norm__6*exp(energy/kT__5)/(kT__5**6*(exp(energy/kT__5) - 1)**2) - 32.21*energy**2*norm__6/(kT__5**5*(exp(energy/kT__5) - 1)))'),
#                            ('norm__6',
#                             '8.0525*energy**3/(kT__5**4*(exp(energy/kT__5) - 1))'),
#                            ('PhoIndex__7',
#                             '-energy*energy**(-PhoIndex__7)*norm__8*log(energy)'),
#                            ('norm__8', 'energy*energy**(-PhoIndex__7)')])),
#              ('cutoffpl+bbody+powerlaw',
#               OrderedDict([('PhoIndex__1',
#                             '-energy*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)*log(energy)'),
#                            ('HighECut__2',
#                             'energy**2*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)/HighECut__2**2'),
#                            ('norm__3',
#                             'energy*energy**(-PhoIndex__1)*exp(-energy/HighECut__2)'),
#                            ('kT__4',
#                             'energy*(8.0525*energy**3*norm__5*exp(energy/kT__4)/(kT__4**6*(exp(energy/kT__4) - 1)**2) - 32.21*energy**2*norm__5/(kT__4**5*(exp(energy/kT__4) - 1)))'),
#                            ('norm__5',
#                             '8.0525*energy**3/(kT__4**4*(exp(energy/kT__4) - 1))'),
#                            ('PhoIndex__6',
#                             '-energy*energy**(-PhoIndex__6)*norm__7*log(energy)'),
#                            ('norm__7', 'energy*energy**(-PhoIndex__6)')])),
#              ('bbody+lpow',
#               OrderedDict([('kT__1',
#                             'energy*(8.0525*energy**3*norm__2*exp(energy/kT__1)/(kT__1**6*(exp(energy/kT__1) - 1)**2) - 32.21*energy**2*norm__2/(kT__1**5*(exp(energy/kT__1) - 1)))'),
#                            ('norm__2',
#                             '8.0525*energy**3/(kT__1**4*(exp(energy/kT__1) - 1))'),
#                            ('plIndex__3',
#                             'energy*norm__4*(0.01*energy)**plIndex__3*log(0.01*energy)'),
#                            ('norm__4', 'energy*(0.01*energy)**plIndex__3')])),
#              ('bbody+powerlaw',
#               OrderedDict([('kT__1',
#                             'energy*(8.0525*energy**3*norm__2*exp(energy/kT__1)/(kT__1**6*(exp(energy/kT__1) - 1)**2) - 32.21*energy**2*norm__2/(kT__1**5*(exp(energy/kT__1) - 1)))'),
#                            ('norm__2',
#                             '8.0525*energy**3/(kT__1**4*(exp(energy/kT__1) - 1))'),
#                            ('PhoIndex__3',
#                             '-energy*energy**(-PhoIndex__3)*norm__4*log(energy)'),
#                            ('norm__4', 'energy*energy**(-PhoIndex__3)')]))])

# %%
# Save dict to a JSON file.

with open('xspec_functions_partial_derivatives.json', 'w') as json_file:
    json.dump(allPartials, json_file, indent=4)

# %% [markdown]
# # Epeak partial derivatvies
# Only models with 'grbm', 'sbpl', or 'cutoffpl' in their names will have a characteristic energy that can be converted to an $E_{pk}$ energy. So we only want to save the partial derivatives for those models.
#
# These partial derivatives are different from those computed above, since we are not taking derivatives of the functions themselves, but their conversion equations from their characteristic energies to $E_{pk}$.

# %%
i = 0
for model in deriv.modelnameOptions:
    # This (below) only allows the appropriate models.
    if any(map(lambda x: x in model, ['grbm', 'sbpl', 'cutoffpl'])):
        print(i, model)
        i += 1
# Out:
# (0, 'grbm')
# (1, 'sbpl')
# (2, 'cutoffpl')
# (3, 'grbm+lpow')
# (4, 'sbpl+lpow')
# (5, 'cutoffpl+lpow')
# (6, 'grbm+powerlaw')
# (7, 'sbpl+powerlaw')
# (8, 'cutoffpl+powerlaw')
# (9, 'grbm+bbody')
# (10, 'sbpl+bbody')
# (11, 'cutoffpl+bbody')
# (12, 'grbm+bbody+lpow')
# (13, 'sbpl+bbody+lpow')
# (14, 'cutoffpl+bbody+lpow')
# (15, 'grbm+bbody+powerlaw')
# (16, 'sbpl+bbody+powerlaw')
# (17, 'cutoffpl+bbody+powerlaw')

# %%
# Compute all partial derivatives (of Epeak conversion equations)
#   wrt each parameter and store in an ordered dict.

epeakPartials = OrderedDict()

for model in deriv.modelnameOptions:
    if any(map(lambda x: x in model, ['grbm', 'sbpl', 'cutoffpl'])):
        epeakPartials[model] = deriv.calc_partial_derivatives( \
                                             modelname=model, 
                                             dpar=None, 
                                             epeakUnc=True)

# %%
# Save dict to a JSON file.

with open('xspec_epeak_partial_derivatives.json', 'w') as json_file:
    json.dump(allPartials, json_file, indent=4)

# %% [markdown]
# # Loading these OrderedDict from JSON
# Use `object_pairs_hook=OrderedDict` so that the dictionary stays in order.

# %%
f = 'xspec_functions_partial_derivatives.json'
partials = json.load(open(f, 'r'), object_pairs_hook=OrderedDict)

# %%
partials
# Out:
# OrderedDict([(u'powerlaw',
#               OrderedDict([(u'PhoIndex__1',
#                             u'-energy*energy**(-PhoIndex__1)*norm__2*log(energy)'),
#                            (u'norm__2', u'energy*energy**(-PhoIndex__1)')])),
#              (u'lpow',
#               OrderedDict([(u'plIndex__1',
#                             u'energy*norm__2*(0.01*energy)**plIndex__1*log(0.01*energy)'),
#                            (u'norm__2',
#                             u'energy*(0.01*energy)**plIndex__1')])),
#              (u'bbody',
#               OrderedDict([(u'kT__1',
#                             u'8.0525*energy**4*norm__2*exp(energy/kT__1)/(kT__1**6*(exp(energy/kT__1) - 1)**2) - 32.21*energy**3*norm__2/(kT__1**5*(exp(energy/kT__1) - 1))'),
#                            (u'norm__2',
#                             u'8.0525*energy**3/(kT__1**4*(exp(energy/kT__1) - 1))')])),
#              (u'grbm',
#               OrderedDict([(u'alpha__1',
#                             [u'energy*norm__4*(0.01*energy)**alpha__1*exp(-energy/tem__3)*log(0.01*energy)',
#                              u'energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(log(0.01*tem__3*(alpha__1 - beta__2)) + 1.0)*exp(-alpha__1 + beta__2) - energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)']),
#                            (u'beta__2',
#                             u'energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(-log(0.01*tem__3*(alpha__1 - beta__2)) - 1.0)*exp(-alpha__1 + beta__2) + energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)*log(0.01*energy) + energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)'),
#                            (u'tem__3',
#                             u'100.0*energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(0.01*alpha__1 - 0.01*beta__2)*exp(-alpha__1 + beta__2)/tem__3'),
#                            (u'norm__4',
#                             u'energy*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)')])),
#              (u'sbpl',
#               OrderedDict([(u'alpha__1',
#                             u'10**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(0.15*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) - 0.15*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*log(10) + 0.5*10**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy)'),
#                            (u'beta__2',
#                             u'10**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(-0.15*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + 0.15*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*log(10) + 0.5*10**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy)'),
#                            (u'ebreak__3',
#                             u'10**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*((-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(energy/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(energy/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))) - (-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(100.0/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(100.0/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))))*log(10)'),
#                            (u'norm__4',
#                             u'10**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)')])),
#              (u'cutoffpl',
#               OrderedDict([(u'PhoIndex__1',
#                             u'-energy*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)*log(energy)'),
#                            (u'HighECut__2',
#                             u'energy**2*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)/HighECut__2**2'),
#                            (u'norm__3',
#                             u'energy*energy**(-PhoIndex__1)*exp(-energy/HighECut__2)')])),
#              (u'grbm+lpow',
#               OrderedDict([(u'alpha__1',
#                             [u'energy*norm__4*(0.01*energy)**alpha__1*exp(-energy/tem__3)*log(0.01*energy)',
#                              u'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(log(0.01*tem__3*(alpha__1 - beta__2)) + 1.0)*exp(-alpha__1 + beta__2) - norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))']),
#                            (u'beta__2',
#                             u'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(-log(0.01*tem__3*(alpha__1 - beta__2)) - 1.0)*exp(-alpha__1 + beta__2) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)*log(0.01*energy) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))'),
#                            (u'tem__3',
#                             u'100.0*energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(0.01*alpha__1 - 0.01*beta__2)*exp(-alpha__1 + beta__2)/tem__3'),
#                            (u'norm__4',
#                             u'energy*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)'),
#                            (u'plIndex__5',
#                             u'energy*norm__6*(0.01*energy)**plIndex__5*log(0.01*energy)'),
#                            (u'norm__6',
#                             u'energy*(0.01*energy)**plIndex__5')])),
#              (u'sbpl+lpow',
#               OrderedDict([(u'alpha__1',
#                             u'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) - 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            (u'beta__2',
#                             u'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(-0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            (u'ebreak__3',
#                             u'10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(energy/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(energy/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))) - 2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(100.0/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(100.0/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))))'),
#                            (u'norm__4',
#                             u'10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)'),
#                            (u'plIndex__5',
#                             u'energy*norm__6*(0.01*energy)**plIndex__5*log(0.01*energy)'),
#                            (u'norm__6',
#                             u'energy*(0.01*energy)**plIndex__5')])),
#              (u'cutoffpl+lpow',
#               OrderedDict([(u'PhoIndex__1',
#                             u'-energy*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)*log(energy)'),
#                            (u'HighECut__2',
#                             u'energy**2*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)/HighECut__2**2'),
#                            (u'norm__3',
#                             u'energy*energy**(-PhoIndex__1)*exp(-energy/HighECut__2)'),
#                            (u'plIndex__4',
#                             u'energy*norm__5*(0.01*energy)**plIndex__4*log(0.01*energy)'),
#                            (u'norm__5',
#                             u'energy*(0.01*energy)**plIndex__4')])),
#              (u'grbm+powerlaw',
#               OrderedDict([(u'alpha__1',
#                             [u'energy*norm__4*(0.01*energy)**alpha__1*exp(-energy/tem__3)*log(0.01*energy)',
#                              u'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(log(0.01*tem__3*(alpha__1 - beta__2)) + 1.0)*exp(-alpha__1 + beta__2) - norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))']),
#                            (u'beta__2',
#                             u'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(-log(0.01*tem__3*(alpha__1 - beta__2)) - 1.0)*exp(-alpha__1 + beta__2) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)*log(0.01*energy) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))'),
#                            (u'tem__3',
#                             u'100.0*energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(0.01*alpha__1 - 0.01*beta__2)*exp(-alpha__1 + beta__2)/tem__3'),
#                            (u'norm__4',
#                             u'energy*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)'),
#                            (u'PhoIndex__5',
#                             u'-energy*energy**(-PhoIndex__5)*norm__6*log(energy)'),
#                            (u'norm__6', u'energy*energy**(-PhoIndex__5)')])),
#              (u'sbpl+powerlaw',
#               OrderedDict([(u'alpha__1',
#                             u'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) - 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            (u'beta__2',
#                             u'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(-0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            (u'ebreak__3',
#                             u'10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(energy/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(energy/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))) - 2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(100.0/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(100.0/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))))'),
#                            (u'norm__4',
#                             u'10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)'),
#                            (u'PhoIndex__5',
#                             u'-energy*energy**(-PhoIndex__5)*norm__6*log(energy)'),
#                            (u'norm__6', u'energy*energy**(-PhoIndex__5)')])),
#              (u'cutoffpl+powerlaw',
#               OrderedDict([(u'PhoIndex__1',
#                             u'-energy*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)*log(energy)'),
#                            (u'HighECut__2',
#                             u'energy**2*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)/HighECut__2**2'),
#                            (u'norm__3',
#                             u'energy*energy**(-PhoIndex__1)*exp(-energy/HighECut__2)'),
#                            (u'PhoIndex__4',
#                             u'-energy*energy**(-PhoIndex__4)*norm__5*log(energy)'),
#                            (u'norm__5', u'energy*energy**(-PhoIndex__4)')])),
#              (u'grbm+bbody',
#               OrderedDict([(u'alpha__1',
#                             [u'energy*norm__4*(0.01*energy)**alpha__1*exp(-energy/tem__3)*log(0.01*energy)',
#                              u'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(log(0.01*tem__3*(alpha__1 - beta__2)) + 1.0)*exp(-alpha__1 + beta__2) - norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))']),
#                            (u'beta__2',
#                             u'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(-log(0.01*tem__3*(alpha__1 - beta__2)) - 1.0)*exp(-alpha__1 + beta__2) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)*log(0.01*energy) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))'),
#                            (u'tem__3',
#                             u'100.0*energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(0.01*alpha__1 - 0.01*beta__2)*exp(-alpha__1 + beta__2)/tem__3'),
#                            (u'norm__4',
#                             u'energy*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)'),
#                            (u'kT__5',
#                             u'energy*(8.0525*energy**3*norm__6*exp(energy/kT__5)/(kT__5**6*(exp(energy/kT__5) - 1)**2) - 32.21*energy**2*norm__6/(kT__5**5*(exp(energy/kT__5) - 1)))'),
#                            (u'norm__6',
#                             u'8.0525*energy**3/(kT__5**4*(exp(energy/kT__5) - 1))')])),
#              (u'sbpl+bbody',
#               OrderedDict([(u'alpha__1',
#                             u'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) - 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            (u'beta__2',
#                             u'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(-0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            (u'ebreak__3',
#                             u'10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(energy/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(energy/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))) - 2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(100.0/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(100.0/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))))'),
#                            (u'norm__4',
#                             u'10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)'),
#                            (u'kT__5',
#                             u'energy*(8.0525*energy**3*norm__6*exp(energy/kT__5)/(kT__5**6*(exp(energy/kT__5) - 1)**2) - 32.21*energy**2*norm__6/(kT__5**5*(exp(energy/kT__5) - 1)))'),
#                            (u'norm__6',
#                             u'8.0525*energy**3/(kT__5**4*(exp(energy/kT__5) - 1))')])),
#              (u'cutoffpl+bbody',
#               OrderedDict([(u'PhoIndex__1',
#                             u'-energy*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)*log(energy)'),
#                            (u'HighECut__2',
#                             u'energy**2*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)/HighECut__2**2'),
#                            (u'norm__3',
#                             u'energy*energy**(-PhoIndex__1)*exp(-energy/HighECut__2)'),
#                            (u'kT__4',
#                             u'energy*(8.0525*energy**3*norm__5*exp(energy/kT__4)/(kT__4**6*(exp(energy/kT__4) - 1)**2) - 32.21*energy**2*norm__5/(kT__4**5*(exp(energy/kT__4) - 1)))'),
#                            (u'norm__5',
#                             u'8.0525*energy**3/(kT__4**4*(exp(energy/kT__4) - 1))')])),
#              (u'grbm+bbody+lpow',
#               OrderedDict([(u'alpha__1',
#                             [u'energy*norm__4*(0.01*energy)**alpha__1*exp(-energy/tem__3)*log(0.01*energy)',
#                              u'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(log(0.01*tem__3*(alpha__1 - beta__2)) + 1.0)*exp(-alpha__1 + beta__2) - norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))']),
#                            (u'beta__2',
#                             u'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(-log(0.01*tem__3*(alpha__1 - beta__2)) - 1.0)*exp(-alpha__1 + beta__2) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)*log(0.01*energy) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))'),
#                            (u'tem__3',
#                             u'100.0*energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(0.01*alpha__1 - 0.01*beta__2)*exp(-alpha__1 + beta__2)/tem__3'),
#                            (u'norm__4',
#                             u'energy*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)'),
#                            (u'kT__5',
#                             u'energy*(8.0525*energy**3*norm__6*exp(energy/kT__5)/(kT__5**6*(exp(energy/kT__5) - 1)**2) - 32.21*energy**2*norm__6/(kT__5**5*(exp(energy/kT__5) - 1)))'),
#                            (u'norm__6',
#                             u'8.0525*energy**3/(kT__5**4*(exp(energy/kT__5) - 1))'),
#                            (u'plIndex__7',
#                             u'energy*norm__8*(0.01*energy)**plIndex__7*log(0.01*energy)'),
#                            (u'norm__8',
#                             u'energy*(0.01*energy)**plIndex__7')])),
#              (u'sbpl+bbody+lpow',
#               OrderedDict([(u'alpha__1',
#                             u'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) - 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            (u'beta__2',
#                             u'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(-0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            (u'ebreak__3',
#                             u'10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(energy/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(energy/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))) - 2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(100.0/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(100.0/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))))'),
#                            (u'norm__4',
#                             u'10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)'),
#                            (u'kT__5',
#                             u'energy*(8.0525*energy**3*norm__6*exp(energy/kT__5)/(kT__5**6*(exp(energy/kT__5) - 1)**2) - 32.21*energy**2*norm__6/(kT__5**5*(exp(energy/kT__5) - 1)))'),
#                            (u'norm__6',
#                             u'8.0525*energy**3/(kT__5**4*(exp(energy/kT__5) - 1))'),
#                            (u'plIndex__7',
#                             u'energy*norm__8*(0.01*energy)**plIndex__7*log(0.01*energy)'),
#                            (u'norm__8',
#                             u'energy*(0.01*energy)**plIndex__7')])),
#              (u'cutoffpl+bbody+lpow',
#               OrderedDict([(u'PhoIndex__1',
#                             u'-energy*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)*log(energy)'),
#                            (u'HighECut__2',
#                             u'energy**2*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)/HighECut__2**2'),
#                            (u'norm__3',
#                             u'energy*energy**(-PhoIndex__1)*exp(-energy/HighECut__2)'),
#                            (u'kT__4',
#                             u'energy*(8.0525*energy**3*norm__5*exp(energy/kT__4)/(kT__4**6*(exp(energy/kT__4) - 1)**2) - 32.21*energy**2*norm__5/(kT__4**5*(exp(energy/kT__4) - 1)))'),
#                            (u'norm__5',
#                             u'8.0525*energy**3/(kT__4**4*(exp(energy/kT__4) - 1))'),
#                            (u'plIndex__6',
#                             u'energy*norm__7*(0.01*energy)**plIndex__6*log(0.01*energy)'),
#                            (u'norm__7',
#                             u'energy*(0.01*energy)**plIndex__6')])),
#              (u'grbm+bbody+powerlaw',
#               OrderedDict([(u'alpha__1',
#                             [u'energy*norm__4*(0.01*energy)**alpha__1*exp(-energy/tem__3)*log(0.01*energy)',
#                              u'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(log(0.01*tem__3*(alpha__1 - beta__2)) + 1.0)*exp(-alpha__1 + beta__2) - norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))']),
#                            (u'beta__2',
#                             u'energy*(norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(-log(0.01*tem__3*(alpha__1 - beta__2)) - 1.0)*exp(-alpha__1 + beta__2) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)*log(0.01*energy) + norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2))'),
#                            (u'tem__3',
#                             u'100.0*energy*norm__4*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*(0.01*alpha__1 - 0.01*beta__2)*exp(-alpha__1 + beta__2)/tem__3'),
#                            (u'norm__4',
#                             u'energy*(0.01*energy)**beta__2*(0.01*tem__3*(alpha__1 - beta__2))**(alpha__1 - beta__2)*exp(-alpha__1 + beta__2)'),
#                            (u'kT__5',
#                             u'energy*(8.0525*energy**3*norm__6*exp(energy/kT__5)/(kT__5**6*(exp(energy/kT__5) - 1)**2) - 32.21*energy**2*norm__6/(kT__5**5*(exp(energy/kT__5) - 1)))'),
#                            (u'norm__6',
#                             u'8.0525*energy**3/(kT__5**4*(exp(energy/kT__5) - 1))'),
#                            (u'PhoIndex__7',
#                             u'-energy*energy**(-PhoIndex__7)*norm__8*log(energy)'),
#                            (u'norm__8', u'energy*energy**(-PhoIndex__7)')])),
#              (u'sbpl+bbody+powerlaw',
#               OrderedDict([(u'alpha__1',
#                             u'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) - 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            (u'beta__2',
#                             u'energy*(10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(-0.345387763949107*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + 0.345387763949107*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10)))) + 0.5*10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*log(0.01*energy))'),
#                            (u'ebreak__3',
#                             u'10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*norm__4*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)*(2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(energy/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(energy/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))) - 2.30258509299405*(-0.15*alpha__1 + 0.15*beta__2)*(1.66666666666667*(100.0/ebreak__3)**(-3.33333333333333/log(10))/(ebreak__3*log(10)) - 1.66666666666667*(100.0/ebreak__3)**(3.33333333333333/log(10))/(ebreak__3*log(10)))/(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))))'),
#                            (u'norm__4',
#                             u'10.0**(-(-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(100.0/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(100.0/ebreak__3)**(3.33333333333333/log(10))) + (-0.15*alpha__1 + 0.15*beta__2)*log(0.5*(energy/ebreak__3)**(-3.33333333333333/log(10)) + 0.5*(energy/ebreak__3)**(3.33333333333333/log(10))))*energy*(0.01*energy)**(0.5*alpha__1 + 0.5*beta__2)'),
#                            (u'kT__5',
#                             u'energy*(8.0525*energy**3*norm__6*exp(energy/kT__5)/(kT__5**6*(exp(energy/kT__5) - 1)**2) - 32.21*energy**2*norm__6/(kT__5**5*(exp(energy/kT__5) - 1)))'),
#                            (u'norm__6',
#                             u'8.0525*energy**3/(kT__5**4*(exp(energy/kT__5) - 1))'),
#                            (u'PhoIndex__7',
#                             u'-energy*energy**(-PhoIndex__7)*norm__8*log(energy)'),
#                            (u'norm__8', u'energy*energy**(-PhoIndex__7)')])),
#              (u'cutoffpl+bbody+powerlaw',
#               OrderedDict([(u'PhoIndex__1',
#                             u'-energy*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)*log(energy)'),
#                            (u'HighECut__2',
#                             u'energy**2*energy**(-PhoIndex__1)*norm__3*exp(-energy/HighECut__2)/HighECut__2**2'),
#                            (u'norm__3',
#                             u'energy*energy**(-PhoIndex__1)*exp(-energy/HighECut__2)'),
#                            (u'kT__4',
#                             u'energy*(8.0525*energy**3*norm__5*exp(energy/kT__4)/(kT__4**6*(exp(energy/kT__4) - 1)**2) - 32.21*energy**2*norm__5/(kT__4**5*(exp(energy/kT__4) - 1)))'),
#                            (u'norm__5',
#                             u'8.0525*energy**3/(kT__4**4*(exp(energy/kT__4) - 1))'),
#                            (u'PhoIndex__6',
#                             u'-energy*energy**(-PhoIndex__6)*norm__7*log(energy)'),
#                            (u'norm__7', u'energy*energy**(-PhoIndex__6)')])),
#              (u'bbody+lpow',
#               OrderedDict([(u'kT__1',
#                             u'energy*(8.0525*energy**3*norm__2*exp(energy/kT__1)/(kT__1**6*(exp(energy/kT__1) - 1)**2) - 32.21*energy**2*norm__2/(kT__1**5*(exp(energy/kT__1) - 1)))'),
#                            (u'norm__2',
#                             u'8.0525*energy**3/(kT__1**4*(exp(energy/kT__1) - 1))'),
#                            (u'plIndex__3',
#                             u'energy*norm__4*(0.01*energy)**plIndex__3*log(0.01*energy)'),
#                            (u'norm__4',
#                             u'energy*(0.01*energy)**plIndex__3')])),
#              (u'bbody+powerlaw',
#               OrderedDict([(u'kT__1',
#                             u'energy*(8.0525*energy**3*norm__2*exp(energy/kT__1)/(kT__1**6*(exp(energy/kT__1) - 1)**2) - 32.21*energy**2*norm__2/(kT__1**5*(exp(energy/kT__1) - 1)))'),
#                            (u'norm__2',
#                             u'8.0525*energy**3/(kT__1**4*(exp(energy/kT__1) - 1))'),
#                            (u'PhoIndex__3',
#                             u'-energy*energy**(-PhoIndex__3)*norm__4*log(energy)'),
#                            (u'norm__4', u'energy*energy**(-PhoIndex__3)')]))])
